# %% [markdown]
# # Task -2

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import warnings
warnings.filterwarnings('ignore')
from sklearn import preprocessing

# %%
data= pd.read_csv('C:/Users/hp/Desktop/Remote Intership2020/Data sets/diabetes.csv')

# %%
data
# Out:
#      preg   plas  pres  Skin   test  mass   pedi  age  class
# 0       6    148    72     35     0  33.6  0.627   50      1
# 1       1     85    66     29     0  26.6  0.351   31      0
# 2       8    183    64      0     0  23.3  0.672   32      1
# 3       1     89    66     23    94  28.1  0.167   21      0
# 4       0    137    40     35   168  43.1  2.288   33      1
# ..    ...    ...   ...    ...   ...   ...    ...  ...    ...
# 763    10    101    76     48   180  32.9  0.171   63      0
# 764     2    122    70     27     0  36.8  0.340   27      0
# 765     5    121    72     23   112  26.2  0.245   30      0
# 766     1    126    60      0     0  30.1  0.349   47      1
# 767     1     93    70     31     0  30.4  0.315   23      0
#
# [768 rows x 9 columns]

# %%
data.shape
# Out:
# (768, 9)

# %%
data.groupby("class").size()
# Out:
# class
# 0    500
# 1    268
# dtype: int64

# %% [markdown]
# # Histogram

# %%
data.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000018FEEB01D08>,
# ...
#       dtype=object)

# %% [markdown]
# # Box plots

# %%
data.plot(kind= 'box' , subplots=True, layout=(3,3), sharex=False, sharey=False, figsize=(25,18))
# Out:
# preg        AxesSubplot(0.125,0.657941;0.227941x0.222059)
#  plas    AxesSubplot(0.398529,0.657941;0.227941x0.222059)
# pres     AxesSubplot(0.672059,0.657941;0.227941x0.222059)
# Skin        AxesSubplot(0.125,0.391471;0.227941x0.222059)
# test     AxesSubplot(0.398529,0.391471;0.227941x0.222059)
# mass     AxesSubplot(0.672059,0.391471;0.227941x0.222059)
# pedi           AxesSubplot(0.125,0.125;0.227941x0.222059)
# age         AxesSubplot(0.398529,0.125;0.227941x0.222059)
# class       AxesSubplot(0.672059,0.125;0.227941x0.222059)
# dtype: object

# %% [markdown]
# # Scatter plot

# %%
plt.scatter(data['mass'],data['age'])
plt.xlabel('MASS')
plt.ylabel('AGE')
plt.title('Scatter plot on Diabetes dataset')
# Out:
# Text(0.5, 1.0, 'Scatter plot on Diabetes dataset')

# %% [markdown]
# # Pair Plot

# %%
sns.set_style("whitegrid");
sns.pairplot(data, hue=None, size=6);
plt.show()

# %% [markdown]
# #

# %%
column_x = data.columns[0:len(data.columns) - 1]
column_x
# Out:
# Index(['preg', ' plas', 'pres', 'Skin ', 'test', 'mass', 'pedi', 'age'], dtype='object')

# %%
corr = data[data.columns].corr()

# %%
sns.heatmap(corr, annot = True)
